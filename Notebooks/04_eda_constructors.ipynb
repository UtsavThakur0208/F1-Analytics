# %%
# ============================================================
# NOTEBOOK 4: Constructor EDA
# ============================================================

import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go

master = pd.read_csv("/content/drive/MyDrive/f1-analytics/data/processed/processedmaster_df.csv")
constructor_stats = pd.read_csv("/content/drive/MyDrive/f1-analytics/data/processed/processedconstructor_season_stats.csv")

master_modern = master[master['year'] >= 2000].copy()
constructor_stats_modern = constructor_stats[constructor_stats['year'] >= 2000].copy()

# %%
# ── ANALYSIS 1: CONSTRUCTOR WIN DOMINANCE ─────────────────────

constructor_wins = (
    master_modern[master_modern['is_winner'] == 1]
    .groupby('constructor_name')['is_winner']
    .sum()
    .sort_values(ascending=True)
    .tail(12)
    .reset_index()
)
constructor_wins.columns = ['Constructor', 'Wins']

fig5 = px.bar(
    constructor_wins,
    x='Wins',
    y='Constructor',
    orientation='h',
    title='Constructor Wins — 2000 to Present',
    color='Wins',
    color_continuous_scale='Blues',
    text='Wins'
)
fig5.update_layout(plot_bgcolor='white', paper_bgcolor='white', coloraxis_showscale=False)
fig5.update_traces(textposition='outside')
fig5.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d3516463-3c75-4e53-a298-c172bbc21924" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d3516463-3c75-4e53-a298-c172bbc21924")) {                    Plotly.newPlot(                        "d3516463-3c75-4e53-a298-c172bbc21924",                        [{"alignmentgroup":"True","hovertemplate":"Wins=%{marker.color}\u003cbr\u003eConstructor=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[1,1,1,1,2,8,11,20,66,120,122,123],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"text":[1.0,1.0,1.0,1.0,2.0,8.0,11.0,20.0,66.0,120.0,122.0,123.0],"textposition":"outside","x":[1,1,1,1,2,8,11,20,66,120,122,123],"xaxis":"x","y":["Honda","Jordan","Racing Point","Toro Rosso","Lotus F1","Brawn","Williams","Renault","McLaren","Mercedes","Red Bull","Ferrari"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2 ...

# %%
# ── ANALYSIS 2: CONSTRUCTOR POINTS TREND ──────────────────────
#
# WHY: Shows dynasty cycles. Ferrari dominated 2000-2004,
# then Red Bull 2010-2013, Mercedes 2014-2021, Red Bull again.
# This narrative makes your project feel like real analysis.

top_constructors = (
    constructor_stats_modern.groupby('constructor_name')['total_points']
    .sum()
    .nlargest(8)
    .index.tolist()
)

trend_data = constructor_stats_modern[
    constructor_stats_modern['constructor_name'].isin(top_constructors)
]

fig6 = px.line(
    trend_data,
    x='year',
    y='total_points',
    color='constructor_name',
    title='Constructor Points Trend — Top 8 Teams (2000-Present)',
    markers=True,
    labels={'total_points': 'Season Points', 'constructor_name': 'Team'}
)
fig6.update_layout(plot_bgcolor='white', paper_bgcolor='white')
fig6.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="9729ebc9-63a5-4d30-894a-479d17775ec6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9729ebc9-63a5-4d30-894a-479d17775ec6")) {                    Plotly.newPlot(                        "9729ebc9-63a5-4d30-894a-479d17775ec6",                        [{"hovertemplate":"Team=Ferrari\u003cbr\u003eyear=%{x}\u003cbr\u003eSeason Points=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Ferrari","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Ferrari","orientation":"v","showlegend":true,"x":[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[170.0,179.0,221.0,158.0,262.0,100.0,201.0,204.0,172.0,70.0,396.0,375.0,400.0,354.0,216.0,428.0,398.0,522.0,571.0,504.0,131.0,322.5,519.0,363.0,595.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Team=Force India\u003cbr\u003eyear=%{x}\u003cbr\u003eSeason Points=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Force India","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Force India","orientation":"v","showlegend":true,"x":[2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018],"xaxis":"x","y":[0.0,13.0,68.0,69.0,109.0,77.0,155.0,136.0,173.0,187.0,111.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Team=Lotus F1\u003cbr\u003eyear=%{x}\u003cbr\u003eSeason Points=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Lotus F1","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Lotus F1","orientation":"v","showlegend":true,"x":[2012,2013,2014,2015],"xaxis":"x","y":[303.0,315.0,10.0,78.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Team=McLaren\u003cbr\u003eyear=%{x}\u003cbr\u003eSeason Points=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"McLaren","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"McLaren","orientation":"v","showlegend":true,"x":[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[162.0,102.0,65.0,142.0,69.0,182.0,110.0,218.0,151.0,71.0,454.0,497.0,378.0,122.0,181.0,27.0,76.0,30.0,62.0,145.0,202.0,274.0,150.0,266.0,609.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Team=Mercedes\u003cbr\u003eyear=%{x}\u003cbr\u003eSeason Points=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Mercedes","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Mercedes","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[214.0,165.0,142.0,360.0,701.0,703.0,765.0,668.0,655.0,739.0,573.0,604.5,495.0,374.0,433.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Team=Red Bull\u003cbr\u003eyear=%{x}\u003cbr\u003eSeason Points=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Red Bull","line":{"color":"#19d3f3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Red Bull","orientation":"v","showlegend":true,"x":[2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[34.0,16.0,24.0,29.0,153.5,498.0,650.0,460.0,596.0,405.0,187.0,468.0,368.0,419.0,417.0,319.0,578.5,724.0,790.0,537.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Team=Renault\u003cbr\u003eyear=%{x}\u003cbr\u003eSeason Points=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Renault","line":{"color":"#FF6692","dash":"solid"},"marker":{"symbol":"circle"}," ...

# %%
# ── ANALYSIS 3: RELIABILITY — DNF RATE BY CONSTRUCTOR ─────────
#
# WHY: A team that's fast but unreliable won't win championships.
# DNF rate is a real engineering KPI used in motorsport.
# This shows you understand the BUSINESS of F1, not just results.

reliability = constructor_stats_modern.groupby('constructor_name').agg(
    total_starts = ('total_races', 'sum'),
    total_dnf    = ('total_dnf', 'sum')
).reset_index()

reliability = reliability[reliability['total_starts'] >= 100]  # enough data
reliability['dnf_rate'] = (reliability['total_dnf'] / reliability['total_starts'] * 100).round(1)
reliability = reliability.sort_values('dnf_rate')

fig7 = px.bar(
    reliability,
    x='dnf_rate',
    y='constructor_name',
    orientation='h',
    title='Constructor DNF Rate (%) — Lower is Better (Min 100 Starts)',
    color='dnf_rate',
    color_continuous_scale='RdYlGn_r',  # red=bad, green=good
    text='dnf_rate'
)
fig7.update_layout(plot_bgcolor='white', paper_bgcolor='white')
fig7.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d8b1fed0-4d12-488a-9161-40b802a6a661" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d8b1fed0-4d12-488a-9161-40b802a6a661")) {                    Plotly.newPlot(                        "d8b1fed0-4d12-488a-9161-40b802a6a661",                        [{"alignmentgroup":"True","hovertemplate":"dnf_rate=%{marker.color}\u003cbr\u003econstructor_name=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[15.1,20.1,27.9,34.3,38.5,41.1,45.0,48.7,50.0,51.2,52.2,57.9,62.0,65.0,65.1,67.4,68.4,68.6,73.3,87.1,88.5,89.3,89.9,99.1,99.5],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"text":[15.1,20.1,27.9,34.3,38.5,41.1,45.0,48.7,50.0,51.2,52.2,57.9,62.0,65.0,65.1,67.4,68.4,68.6,73.3,87.1,88.5,89.3,89.9,99.1,99.5],"textposition":"auto","x":[15.1,20.1,27.9,34.3,38.5,41.1,45.0,48.7,50.0,51.2,52.2,57.9,62.0,65.0,65.1,67.4,68.4,68.6,73.3,87.1,88.5,89.3,89.9,99.1,99.5],"xaxis":"x","y":["Mercedes","Ferrari","Red Bull","BMW Sauber","McLaren","Aston Martin","Alpine F1 Team","Lotus F1","AlphaTauri","Force India","Renault","Williams","Alfa Romeo","Toyota","Honda","Toro Rosso","Haas F1 Team","BAR","Sauber","Jaguar","Jordan","Caterham","Marussia","HRT","Minardi"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888 ...

# %% [markdown]
# Key Insights
# ***Ferrari, Red Bull, and Mercedes*** have been the most successful constructors since 2000, leading the sport in total race wins.
# Constructor dominance has shifted across eras, with Ferrari, Mercedes, and Red Bull each enjoying periods of sustained success.
# Mercedes recorded the lowest DNF rate among major constructors, highlighting exceptional reliability.
# Teams with stronger reliability and consistent point-scoring performance tend to achieve greater long-term success.
# The analysis shows that Formula 1 dominance is driven by a combination of race-winning pace, consistency, and reliability.

# %% [markdown]
# Ferrari, Red Bull, and Mercedes have been the most dominant constructors in Formula 1 since 2000, each recording more than 120 race wins. Ferrari leads the win tally, closely followed by Red Bull and Mercedes, while McLaren remains the only other team with a significant number of victories during this period.
#
# The constructor points trends reveal distinct eras of dominance. Ferrari controlled the early 2000s, Red Bull emerged as a powerhouse during the early 2010s, Mercedes dominated the hybrid era, and Red Bull has once again established itself as the benchmark team in recent seasons. These shifts highlight how competitive advantage changes across different technical and regulatory eras of Formula 1.
#
# Reliability analysis further emphasizes the importance of consistency. Mercedes recorded the lowest DNF rate among constructors with at least 100 starts, demonstrating exceptional reliability throughout its successful years. Red Bull and McLaren also maintained relatively low failure rates, contributing to their sustained competitiveness. In contrast, teams such as Minardi, Marussia, and Jordan experienced significantly higher DNF rates, limiting their ability to consistently score points and compete for wins.
#
#
#
# Overall, the analysis suggests that long-term success in **Formula 1 is not determined by race pace alone**. The ***most successful constructors combine three critical factors: winning performance, consistent point-scoring ability, and strong reliability***
